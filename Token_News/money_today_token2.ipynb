# %%
from ekonlpy.tag import Mecab
import pandas as pd

# Mecab 객체 생성
mecab = Mecab()

# 문장에서 한 글자 단어를 문맥에 맞게 변형하는 함수
def adjust_single_char_tokens(sentence):
    pos_result = mecab.pos(sentence)  # 품사 태깅
    adjusted_sentence = []

    for word, pos in pos_result:
        # 한 글자 단어에 대해 문맥을 고려하여 변형
        if len(word) == 1:
            if pos.startswith('V'):  # 동사인 경우
                adjusted_sentence.append(word + "다")  # "있" => "있다" 같은 형태로 복원
            elif pos.startswith('A'):  # 형용사인 경우
                adjusted_sentence.append(word + "다")  # "좋" => "좋다"
            else:
                adjusted_sentence.append(word)  # 그 외의 경우는 그대로
        else:
            adjusted_sentence.append(word)

    return " ".join(adjusted_sentence)

# 명사, 동사, 형용사, 부사만 추출하는 함수
def extract_clean_tokens_from_pos(pos_tagged):
    # 명사(N), 동사(V), 형용사(A), 부사(M)만 추출
    keywords = [word for word, pos in pos_tagged if pos.startswith(('N', 'V', 'A', 'M')) and pos not in ('J', 'E', 'M')]
    
    # 한 글자 토큰을 문맥에 맞게 변형
    adjusted_keywords = [adjust_single_char_tokens(word) for word in keywords]
    
    return adjusted_keywords

# CSV 파일 읽기
df = pd.read_csv(r"C:/Users/wosle/OneDrive/Desktop/프로젝트 파일/뉴스 클랜징/머니투데이/머니투데이전처리3.csv", encoding="utf-8-sig")

# 저장할 경로 설정
output_base_folder = r"C:/Users/wosle/OneDrive/Desktop/프로젝트 파일/뉴스 클랜징/머니투데이/토큰화"

# 년도별로 데이터 분리하여 저장
for year in df['date'].apply(lambda x: pd.to_datetime(x).year).unique():
    # 해당 년도의 데이터 필터링
    year_df = df[df['date'].apply(lambda x: pd.to_datetime(x).year == year)]
    
    # 월별로 데이터 나누어 저장
    for month in range(1, 13):
        # 해당 월의 데이터 필터링
        month_df = year_df[year_df['date'].apply(lambda x: pd.to_datetime(x).month == month)]
        
        if month_df.empty:
            continue  # 데이터가 없으면 건너뜀
        
        # 폴더 생성 (해당 년도와 월에 맞는 폴더)
        folder_name = f"{year}-{str(month).zfill(2)}"
        output_folder = os.path.join(output_base_folder, folder_name)
        os.makedirs(output_folder, exist_ok=True)  # 폴더가 없으면 생성
        
        # 품사 태깅 적용 (ekonlpy 사용)
        month_df["pos_tagged"] = month_df["orgn_sntc"].apply(lambda x: mecab.pos(str(x)))
        
        # 클린 토큰만 추출 (명사, 동사, 형용사, 부사 포함)
        month_df["clean_token"] = month_df["pos_tagged"].apply(extract_clean_tokens_from_pos)
        
        # 첫 번째 날짜와 마지막 날짜 추출 (파일명에 반영)
        first_date = month_df['date'].min()
        last_date = month_df['date'].max()
        
        # 새로운 파일명 생성 (예: token_edaily_200801.csv)
        new_filename = f"token_money_today_{first_date[:4]}{first_date[5:7]}.csv"
        output_path = os.path.join(output_folder, new_filename)
        
        # pos_tagged 열 제거 후 파일 저장 (클린 토큰만 포함)
        month_df.drop(columns=['pos_tagged'], inplace=True)
        
        # 파일 저장
        month_df.to_csv(output_path, index=False, encoding="utf-8-sig", quoting=1)
        print(f"{new_filename}로 저장 완료.")
# Out:
# C:\Users\wosle\AppData\Local\Temp\ipykernel_18780\2369981308.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   month_df["pos_tagged"] = month_df["orgn_sntc"].apply(lambda x: mecab.pos(str(x)))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 69
#      66 month_df["pos_tagged"] = month_df["orgn_sntc"].apply(lambda x: mecab.pos(str(x)))
#      68 # 클린 토큰만 추출 (명사, 동사, 형용사, 부사 포함)
# ---> 69 month_df["clean_token"] = month_df["pos_tagged"].apply(extract_clean_tokens_from_pos)
#      71 # 첫 번째 날짜와 마지막 날짜 추출 (파일명에 반영)
#      72 first_date = month_df['date'].min()
#
# File c:\Users\wosle\anaconda3\envs\crawl\lib\site-packages\pandas\core\series.py:4917, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
# -> 4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
#    4924     ).apply()
#
# File c:\Users\wosle\anaconda3\envs\crawl\lib\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File c:\Users\wosle\anaconda3\envs\crawl\lib\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File c:\Users\wosle\anaconda3\envs\crawl\lib\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File c:\Users\wosle\anaconda3\envs\crawl\lib\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[3], line 35, in extract_clean_tokens_from_pos(pos_tagged)
#      33 for word, pos in pos_tagged:
#      34     if pos.startswith(('N', 'V', 'A', 'M')):  # 명사, 동사, 형용사, 부사만 선택
# ---> 35         lemma = okt.morphs(word)  # 원형 복원 적용
#      36         clean_tokens.extend(lemma)
#      38 # 한 글자 단어를 문맥에 맞게 변형
#
# File c:\Users\wosle\anaconda3\envs\crawl\lib\site-packages\konlpy\tag\_okt.py:89, in Okt.morphs(self, phrase, norm, stem)
#      86 def morphs(self, phrase, norm=False, stem=False):
#      87     """Parse phrase to morphemes."""
# ---> 89     return [s for s, t in self.pos(phrase, norm=norm, stem=stem)]
#
# File c:\Users\wosle\anaconda3\envs\crawl\lib\site-packages\konlpy\tag\_okt.py:71, in Okt.pos(self, phrase, norm, stem, join)
#      59 """POS tagger.
#      60 In contrast to other classes in this subpackage,
#      61 this POS tagger doesn't have a `flatten` option,
#    (...)
#      67 :param join: If True, returns joined sets of morph and tag.
#      68 """
#      69 validate_phrase_inputs(phrase)
# ---> 71 tokens = self.jki.tokenize(
#      72             phrase,
#      73             jpype.java.lang.Boolean(norm),
#      74             jpype.java.lang.Boolean(stem)).toArray()
#      75 if join:
#      76     return [t for t in tokens]
#
# KeyboardInterrupt:
