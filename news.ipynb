# %%
from selenium import webdriver 
from bs4 import BeautifulSoup
import time
import csv
import os
from datetime import datetime, timedelta

# 1. 날짜 및 초기 설정
ds = "2008.01.01"  # 시작 날짜 (YYYY.MM.DD 형식)
end_date = "2018.12.31"  # 종료 날짜

duration = 7       # 기본 기간 (days)
min_duration = 1   # 최소 기간

# 저장 폴더 설정
save_folder = "e_daily_csv"
os.makedirs(save_folder, exist_ok=True)

# 날짜 형식 변환 함수
def add_days_to_date(date_str, days):
    date_obj = datetime.strptime(date_str, "%Y.%m.%d")
    new_date_obj = date_obj + timedelta(days=days)
    return new_date_obj.strftime("%Y.%m.%d")

while True:
    try:
        # 종료 조건: ds가 end_date를 초과하면 중단
        if datetime.strptime(ds, "%Y.%m.%d") > datetime.strptime(end_date, "%Y.%m.%d"):
            print("크롤링 완료: 설정한 날짜 범위를 초과했습니다.")
            break

        # 2. 종료 날짜 계산
        de = add_days_to_date(ds, duration)
        if datetime.strptime(de, "%Y.%m.%d") > datetime.strptime(end_date, "%Y.%m.%d"):
            de = end_date

        # Selenium 설정
        options = webdriver.ChromeOptions()
        options.add_argument("--headless")  # 브라우저 창을 띄우지 않음
        options.add_argument("--no-sandbox")
        options.add_argument("--disable-dev-shm-usage")
        options.add_argument("user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")

        driver = webdriver.Chrome(options=options)
        url = f"https://search.naver.com/search.naver?where=news&query=%EA%B8%88%EB%A6%AC&sm=tab_opt&sort=2&photo=0&field=0&pd=3&ds={ds}&de={de}&docid=&related=0&mynews=1&office_type=1&office_section_code=3&news_office_checked=1018&nso=so%3Ar%2Cp%3Afrom{ds.replace('.', '')}to{de.replace('.', '')}&is_sug_officeid=0&office_category=0&service_area=0"
        driver.get(url)

        # 무한 스크롤 처리
        SCROLL_PAUSE_TIME = 2  # 스크롤 간 대기 시간

        last_height = driver.execute_script("return document.body.scrollHeight")
        while True:
            driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(SCROLL_PAUSE_TIME)
            new_height = driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        # BeautifulSoup으로 HTML 파싱
        soup = BeautifulSoup(driver.page_source, "html.parser")
        articles = soup.select(".news_wrap")  # 기사 목록 선택자

        # 데이터 수집
        results = []
        for article in articles:
            try:
                url_tag = article.select_one("a.info[href^='https://n.news.naver.com']")
                if url_tag:
                    url = url_tag["href"]
                    date_tag = url_tag.find_previous_sibling("span", class_="info")
                    date = date_tag.text.strip() if date_tag else "날짜 없음"
                    results.append({"url": url, "date": date})
            except Exception as e:
                print(f"Error parsing article: {e}")

        # 결과 저장 (CSV 파일)
        output_filename = os.path.join(save_folder, f"naver_news_{ds.replace('.', '')}_{de.replace('.', '')}_e_daily.csv")
        with open(output_filename, "w", encoding="utf-8-sig", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=["url", "date"])
            writer.writeheader()
            writer.writerows(results)

        print(f"크롤링 완료! 총 수집된 기사: {len(results)}")
        print(f"결과가 저장되었습니다: {output_filename}")
        
        driver.quit()

        # 다음 실행을 위한 ds 업데이트 (de + 1)
        ds = add_days_to_date(de, 1)
        
    except Exception as e:
        print(f"오류 발생: {e}")
        
        # duration을 줄여서 재시도 (최소값은 min_duration)
        duration -= 1
        if duration < min_duration:
            print("최소 기간에 도달하여 크롤링을 중단합니다.")
            break
        
    finally:
        try:
            driver.quit()
        except:
            pass
# Out:
# 크롤링 완료! 총 수집된 기사: 177
# 결과가 저장되었습니다: e_daily_csv\naver_news_20
# 결과가 저장되었습니다: e_daily_csv\naver_news_20130919_20130926_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 127
# 결과가 저장되었습니다: e_daily_csv\naver_news_20130927_20131004_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 121
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131005_20131012_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 120
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131013_20131020_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 134
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131021_20131028_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 166
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131029_20131105_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 144
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131106_20131113_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 166
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131114_20131121_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 117
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131122_20131129_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 124
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131130_20131207_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 129
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131208_20131215_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 166
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131216_20131223_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 94
# 결과가 저장되었습니다: e_daily_csv\naver_news_20131224_20131231_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 163
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140101_20140108_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 177
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140109_20140116_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 120
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140117_20140124_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 100
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140125_20140201_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 128
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140202_20140209_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 180
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140210_20140217_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 150
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140218_20140225_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 143
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140226_20140305_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 146
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140306_20140313_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 185
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140314_20140321_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 167
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140322_20140329_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 131
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140330_20140406_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 141
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140407_20140414_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 122
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140415_20140422_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 121
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140423_20140430_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 91
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140501_20140508_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 177
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140509_20140516_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 105
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140517_20140524_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 107
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140525_20140601_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 121
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140602_20140609_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 158
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140610_20140617_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 137
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140618_20140625_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 163
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140626_20140703_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 224
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140704_20140711_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 178
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140712_20140719_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 180
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140720_20140727_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 180
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140728_20140804_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 220
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140805_20140812_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 190
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140813_20140820_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 206
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140821_20140828_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 192
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140829_20140905_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 130
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140906_20140913_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 211
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140914_20140921_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 196
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140922_20140929_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 193
# 결과가 저장되었습니다: e_daily_csv\naver_news_20140930_20141007_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 231
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141008_20141015_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 204
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141016_20141023_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 202
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141024_20141031_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 169
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141101_20141108_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 184
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141109_20141116_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 209
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141117_20141124_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 188
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141125_20141202_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 224
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141203_20141210_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 247
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141211_20141218_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 176
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141219_20141226_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 142
# 결과가 저장되었습니다: e_daily_csv\naver_news_20141227_20150103_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 192
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150104_20150111_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 280
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150112_20150119_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 221
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150120_20150127_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 268
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150128_20150204_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 243
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150205_20150212_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 127
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150213_20150220_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 202
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150221_20150228_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 194
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150301_20150308_e_daily.csv
# 크롤링 완료! 총 수집된 기사: 385
# 결과가 저장되었습니다: e_daily_csv\naver_news_20150309_20150316_e_daily.csv
# 크롤링 완료! 총 수집된 기사: